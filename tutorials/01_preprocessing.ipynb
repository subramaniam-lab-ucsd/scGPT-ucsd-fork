# %% [markdown]
# # 01 - Preprocessing COVID dataset

# %%
from pathlib import Path
import os
import scanpy as sc
import pandas as pd
import numpy as np
import hdf5plugin

# %%
covidDataPath = Path("../data/covid") # covid data's path

covidData = sc.read(covidDataPath / "covidObj.h5ad") # loading Covid data

# %%
print(f'COVID dataset \n Cells: {covidData.X.shape[0]} \n Genes: {covidData.X.shape[1]}\n')
# Out:
# COVID dataset
#  Cells: 375438
#  Genes: 14063

# %%
covidData.obs
# Out:
#                                  orig.ident  nCount_RNA  nFeature_RNA  \
# 560_cell.588_AGTTGGAGAACG_1        560_cell       285.0           236
# 560_cell.637_TTGACACATACC_1        560_cell       555.0           284
# 560_cell.639_CACCATAAGAAT_1        560_cell       523.0           284
# 560_cell.647_TTGTGAAACAGT_1        560_cell       675.0           295
# 560_cell.652_CTAAGTTGCTTT_1        560_cell       461.0           301
# ...                                     ...         ...           ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5      BN-28      1629.0           659
# AACTGTATTACTATCCTCCTAGATAGA_22_5      BN-05       709.0           390
# CACATTGCAGCTAACTCACAGGCATTT_22_5      BN-28       446.0           310
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5      BN-12       893.0           586
# CAAACCGCCAATTATAACCAGGCATTT_22_5      BN-05       491.0           303
#
#                                  Infection_status    Severity  \
# 560_cell.588_AGTTGGAGAACG_1                 Covid      Severe
# 560_cell.637_TTGACACATACC_1                 Covid      Severe
# 560_cell.639_CACCATAAGAAT_1                 Covid      Severe
# 560_cell.647_TTGTGAAACAGT_1                 Covid      Severe
# 560_cell.652_CTAAGTTGCTTT_1                 Covid      Severe
# ...                                           ...         ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5          Healthy     Healthy
# AACTGTATTACTATCCTCCTAGATAGA_22_5            Covid  Non-severe
# CACATTGCAGCTAACTCACAGGCATTT_22_5          Healthy     Healthy
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5            Covid      Severe
# CAAACCGCCAATTATAACCAGGCATTT_22_5            Covid  Non-severe
#
#                                   log10GenesPerUMI  percent.mt  percent.Heme  \
# 560_cell.588_AGTTGGAGAACG_1               0.800229   11.561265      0.000000
# 560_cell.637_TTGACACATACC_1               0.821141    8.294501     17.334576
# 560_cell.639_CACCATAAGAAT_1               0.828072    2.131783     15.116279
# 560_cell.647_TTGTGAAACAGT_1               0.813503    7.190083     23.636364
# 560_cell.652_CTAAGTTGCTTT_1               0.836481    9.232264      7.580175
# ...                                            ...         ...           ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5          0.882532   21.009867      0.000000
# AACTGTATTACTATCCTCCTAGATAGA_22_5          0.907000   20.129870      0.779221
# CACATTGCAGCTAACTCACAGGCATTT_22_5          0.931754   17.892644      0.397614
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5          0.940330   13.244353      0.410678
# CAAACCGCCAATTATAACCAGGCATTT_22_5          0.924428   19.111969      0.000000
#
#                                   Study  seurat_clusters  new.annot2
# 560_cell.588_AGTTGGAGAACG_1        Wilk               26           4
# 560_cell.637_TTGACACATACC_1        Wilk               34           4
# 560_cell.639_CACCATAAGAAT_1        Wilk               55          14
# 560_cell.647_TTGTGAAACAGT_1        Wilk               10           4
# 560_cell.652_CTAAGTTGCTTT_1        Wilk               50           1
# ...                                 ...              ...         ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5  SS_C2               15           8
# AACTGTATTACTATCCTCCTAGATAGA_22_5  SS_C2               23           4
# CACATTGCAGCTAACTCACAGGCATTT_22_5  SS_C2               23           4
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5  SS_C2               31           2
# CAAACCGCCAATTATAACCAGGCATTT_22_5  SS_C2               26           4
#
# [375438 rows x 11 columns]

# %%
# From Mukund et al. supplementary information 
# URL: https://www.frontiersin.org/journals/immunology/articles/10.3389/fimmu.2021.738073/full#supplementary-material
column_names = [
'cluster',
'number of cells',
'SingleR Annotation',	
'Human_gene_atlas enrichment(of ClusterMarkers)',
'Final Cluster Identities'
]

# Read clusterIdentities.tsv to map cluster number with cluster name
clusterIdentities = pd.read_csv(covidDataPath / 'clusterIdentities.tsv', sep="\t", header=None, names=column_names)
cluster_identity_map = dict(zip(clusterIdentities["cluster"], clusterIdentities["Final Cluster Identities"]))

# Create new metadata column called 'celltype' to assign names to clusters 
covidData.obs['celltype'] = covidData.obs["seurat_clusters"].map(cluster_identity_map).astype("category")

# List of 5 studies to assign adata.obs.batch_id
study_names = [
    'Wilk',
    'Lee',
    'Bali',
    'SS_C1',
    'SS_C2'
    ]

                
# define unique numerical labels for cell types and study
celltype_id_labels = covidData.obs["celltype"].astype("category").cat.codes.values
batch_id_labels = covidData.obs["Study"].astype("category").cat.codes.values


id2type = dict(enumerate(covidData.obs["celltype"].astype("category").cat.categories))
id2batch = dict(enumerate(covidData.obs["Study"].astype("category").cat.categories))

covidData.obs["celltype_id"] = celltype_id_labels
covidData.obs["batch_id"] = batch_id_labels

# Check number of unique cell types and studies in paper

num_types_cell = len(np.unique(celltype_id_labels))
num_types_batch = len(np.unique(batch_id_labels))

print(f"Number of unique final cluster annotations: {num_types_cell}")
print(f"Number of unique studies: {num_types_batch}")

print(id2batch)
print(id2type)
# Out:
# Number of unique final cluster annotations: 20
# Number of unique studies: 5
# {0: 'Bali', 1: 'Lee', 2: 'SS_C1', 3: 'SS_C2', 4: 'Wilk'}
# {0: 'B lymphoblast', 1: 'CD14+ Monocytes', 2: 'CD16+ Monocytes', 3: 'CD34+ Progenitor cells', 4: 'CD4+ T cells', 5: 'CD8+ T cells', 6: 'Intermediate monocytes', 7: 'Low-density basophils', 8: 'Low-density neutrophils', 9: 'MAIT cells', 10: 'Megakaryocytes', 11: 'Myeloid dendritic cells', 12: 'NK cells', 13: 'Naïve B cells', 14: 'Naïve CD4+ T cells', 15: 'Naïve CD8+ T cells', 16: 'Non-switched memory B cells', 17: 'Plasmablasts', 18: 'Plasmacytoid dendritic cells', 19: 'gd T cells'}

# %%
covidData.write_h5ad(covidDataPath/'covidData.h5ad'
                         compression=hdf5plugin.FILTERS["zstd"]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 covidData.write_h5ad(covidDataPath/'covidData.h5ad')
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_core/anndata.py:1863, in AnnData.write_h5ad(self, filename, compression, compression_opts, as_dense)
#    1860 if filename is None:
#    1861     filename = self.filename
# -> 1863 write_h5ad(
#    1864     Path(filename),
#    1865     self,
#    1866     compression=compression,
#    1867     compression_opts=compression_opts,
#    1868     as_dense=as_dense,
#    1869 )
#    1871 if self.isbacked:
#    1872     self.file.filename = filename
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/h5ad.py:100, in write_h5ad(filepath, adata, as_dense, dataset_kwargs, **kwargs)
#      96     write_elem(
#      97         f, "raw/varm", dict(adata.raw.varm), dataset_kwargs=dataset_kwargs
#      98     )
#      99 elif adata.raw is not None:
# --> 100     write_elem(f, "raw", adata.raw, dataset_kwargs=dataset_kwargs)
#     101 write_elem(f, "obs", adata.obs, dataset_kwargs=dataset_kwargs)
#     102 write_elem(f, "var", adata.var, dataset_kwargs=dataset_kwargs)
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/specs/registry.py:378, in write_elem(store, k, elem, dataset_kwargs)
#     354 def write_elem(
#     355     store: GroupStorageType,
#     356     k: str,
#    (...)
#     359     dataset_kwargs: Mapping[str, Any] = MappingProxyType({}),
#     360 ) -> None:
#     361     """
#     362     Write an element to a storage group using anndata encoding.
#     363
#    (...)
#     376         E.g. for zarr this would be `chunks`, `compressor`.
#     377     """
# --> 378     Writer(_REGISTRY).write_elem(store, k, elem, dataset_kwargs=dataset_kwargs)
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/utils.py:247, in report_write_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     245     raise ValueError("No element found in args.")
#     246 try:
# --> 247     return func(*args, **kwargs)
#     248 except Exception as e:
#     249     path = _get_display_path(store)
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/specs/registry.py:328, in Writer.write_elem(self, store, k, elem, dataset_kwargs, modifiers)
#     325 write_func = self.find_write_func(dest_type, elem, modifiers)
#     327 if self.callback is None:
# --> 328     return write_func(store, k, elem, dataset_kwargs=dataset_kwargs)
#     329 return self.callback(
#     330     write_func,
#     331     store,
#    (...)
#     335     iospec=self.registry.get_spec(elem),
#     336 )
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/specs/registry.py:71, in write_spec.<locals>.decorator.<locals>.wrapper(g, k, *args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(g: GroupStorageType, k: str, *args, **kwargs):
# ---> 71     result = func(g, k, *args, **kwargs)
#      72     g[k].attrs.setdefault("encoding-type", spec.encoding_type)
#      73     g[k].attrs.setdefault("encoding-version", spec.encoding_version)
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/specs/methods.py:323, in write_raw(f, k, raw, _writer, dataset_kwargs)
#     321 g = f.require_group(k)
#     322 _writer.write_elem(g, "X", raw.X, dataset_kwargs=dataset_kwargs)
# --> 323 _writer.write_elem(g, "var", raw.var, dataset_kwargs=dataset_kwargs)
#     324 _writer.write_elem(g, "varm", dict(raw.varm), dataset_kwargs=dataset_kwargs)
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/utils.py:247, in report_write_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     245     raise ValueError("No element found in args.")
#     246 try:
# --> 247     return func(*args, **kwargs)
#     248 except Exception as e:
#     249     path = _get_display_path(store)
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/specs/registry.py:328, in Writer.write_elem(self, store, k, elem, dataset_kwargs, modifiers)
#     325 write_func = self.find_write_func(dest_type, elem, modifiers)
#     327 if self.callback is None:
# --> 328     return write_func(store, k, elem, dataset_kwargs=dataset_kwargs)
#     329 return self.callback(
#     330     write_func,
#     331     store,
#    (...)
#     335     iospec=self.registry.get_spec(elem),
#     336 )
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/specs/registry.py:71, in write_spec.<locals>.decorator.<locals>.wrapper(g, k, *args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(g: GroupStorageType, k: str, *args, **kwargs):
# ---> 71     result = func(g, k, *args, **kwargs)
#      72     g[k].attrs.setdefault("encoding-type", spec.encoding_type)
#      73     g[k].attrs.setdefault("encoding-version", spec.encoding_version)
#
# File ~/python39env/lib/python3.9/site-packages/anndata/_io/specs/methods.py:798, in write_dataframe(f, key, df, _writer, dataset_kwargs)
#     796 for reserved in ("_index",):
#     797     if reserved in df.columns:
# --> 798         raise ValueError(f"{reserved!r} is a reserved name for dataframe columns.")
#     799 group = _require_group_write_dataframe(f, key, df)
#     800 if not df.columns.is_unique:
#
# ValueError: '_index' is a reserved name for dataframe columns.
# Error raised while writing key 'var' of <class 'h5py._hl.group.Group'> to /raw

# %%
covidData.var.columns
# Out:
# Index(['features'], dtype='object')

# %%
# Rename features -> gene_name
covidData.var.rename(columns={'features': 'gene_name'}, inplace=True)

# Set gene_name as variable index
covidData.var.set_index(covidData.var["gene_name"], inplace=True)
covidData.var["gene_name"] = covidData.var.index.tolist()
# Out:
#                                  orig.ident  nCount_RNA  nFeature_RNA  \
# 560_cell.588_AGTTGGAGAACG_1        560_cell       285.0           236
# 560_cell.637_TTGACACATACC_1        560_cell       555.0           284
# 560_cell.639_CACCATAAGAAT_1        560_cell       523.0           284
# 560_cell.647_TTGTGAAACAGT_1        560_cell       675.0           295
# 560_cell.652_CTAAGTTGCTTT_1        560_cell       461.0           301
# ...                                     ...         ...           ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5      BN-28      1629.0           659
# AACTGTATTACTATCCTCCTAGATAGA_22_5      BN-05       709.0           390
# CACATTGCAGCTAACTCACAGGCATTT_22_5      BN-28       446.0           310
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5      BN-12       893.0           586
# CAAACCGCCAATTATAACCAGGCATTT_22_5      BN-05       491.0           303
#
#                                  Infection_status    Severity  \
# 560_cell.588_AGTTGGAGAACG_1                 Covid      Severe
# 560_cell.637_TTGACACATACC_1                 Covid      Severe
# 560_cell.639_CACCATAAGAAT_1                 Covid      Severe
# 560_cell.647_TTGTGAAACAGT_1                 Covid      Severe
# 560_cell.652_CTAAGTTGCTTT_1                 Covid      Severe
# ...                                           ...         ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5          Healthy     Healthy
# AACTGTATTACTATCCTCCTAGATAGA_22_5            Covid  Non-severe
# CACATTGCAGCTAACTCACAGGCATTT_22_5          Healthy     Healthy
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5            Covid      Severe
# CAAACCGCCAATTATAACCAGGCATTT_22_5            Covid  Non-severe
#
#                                   log10GenesPerUMI  percent.mt  percent.Heme  \
# 560_cell.588_AGTTGGAGAACG_1               0.800229   11.561265      0.000000
# 560_cell.637_TTGACACATACC_1               0.821141    8.294501     17.334576
# 560_cell.639_CACCATAAGAAT_1               0.828072    2.131783     15.116279
# 560_cell.647_TTGTGAAACAGT_1               0.813503    7.190083     23.636364
# 560_cell.652_CTAAGTTGCTTT_1               0.836481    9.232264      7.580175
# ...                                            ...         ...           ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5          0.882532   21.009867      0.000000
# AACTGTATTACTATCCTCCTAGATAGA_22_5          0.907000   20.129870      0.779221
# CACATTGCAGCTAACTCACAGGCATTT_22_5          0.931754   17.892644      0.397614
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5          0.940330   13.244353      0.410678
# CAAACCGCCAATTATAACCAGGCATTT_22_5          0.924428   19.111969      0.000000
#
#                                   Study  seurat_clusters  new.annot2  \
# 560_cell.588_AGTTGGAGAACG_1        Wilk               26           4
# 560_cell.637_TTGACACATACC_1        Wilk               34           4
# 560_cell.639_CACCATAAGAAT_1        Wilk               55          14
# 560_cell.647_TTGTGAAACAGT_1        Wilk               10           4
# 560_cell.652_CTAAGTTGCTTT_1        Wilk               50           1
# ...                                 ...              ...         ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5  SS_C2               15           8
# AACTGTATTACTATCCTCCTAGATAGA_22_5  SS_C2               23           4
# CACATTGCAGCTAACTCACAGGCATTT_22_5  SS_C2               23           4
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5  SS_C2               31           2
# CAAACCGCCAATTATAACCAGGCATTT_22_5  SS_C2               26           4
#
#                                                  celltype  celltype_id  \
# 560_cell.588_AGTTGGAGAACG_1               CD14+ Monocytes            1
# 560_cell.637_TTGACACATACC_1               CD14+ Monocytes            1
# 560_cell.639_CACCATAAGAAT_1       Low-density neutrophils            8
# 560_cell.647_TTGTGAAACAGT_1               CD14+ Monocytes            1
# 560_cell.652_CTAAGTTGCTTT_1                  CD4+ T cells            4
# ...                                                   ...          ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5               MAIT cells            9
# AACTGTATTACTATCCTCCTAGATAGA_22_5          CD14+ Monocytes            1
# CACATTGCAGCTAACTCACAGGCATTT_22_5          CD14+ Monocytes            1
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5             CD8+ T cells            5
# CAAACCGCCAATTATAACCAGGCATTT_22_5          CD14+ Monocytes            1
#
#                                   batch_id
# 560_cell.588_AGTTGGAGAACG_1              4
# 560_cell.637_TTGACACATACC_1              4
# 560_cell.639_CACCATAAGAAT_1              4
# 560_cell.647_TTGTGAAACAGT_1              4
# 560_cell.652_CTAAGTTGCTTT_1              4
# ...                                    ...
# TGTACCTTACACTCGAGAAAGGGTCAG_22_5         3
# AACTGTATTACTATCCTCCTAGATAGA_22_5         3
# CACATTGCAGCTAACTCACAGGCATTT_22_5         3
# TCTCTTCAACAATTGATCAGCCGCAAG_22_5         3
# CAAACCGCCAATTATAACCAGGCATTT_22_5         3
#
# [375438 rows x 14 columns]
